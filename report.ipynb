# %% [markdown]
# #  2025-2학기 파이썬 프로그래밍 레포트

# %% [markdown]
# ## 문제

# %% [markdown]
# <strong> 학생들의 성적을 계산하는 프로그램을 작성하시오. 이 프로그램은 다음 조건을 만족해야 한다. </strong><br>
#
# 1. 학생 성적 입력<br>
#  - 학생의 이름과 4개의 과목 점수를 입력 받는다.
#  - 각 과목 점수는 0에서 100 사이의 짝수여야 하며, 잘못된 값이 들어오면 "Invalid Value"를 반환한다.
#
# 2. 학점 계산<br>
#  - 각 과목의 평균 점수를 계산하고, 그에 맞는 학점을 부여한다.
#
# |학점 계산 기준 |학점(대문자)|
# |---|---|
# |90점이상 |A|
# |80점 이상 90점 미만|B|
# |70점 이상 80점 미만|C|
# |60점 이상 70점 미만|D|
# |60점 미만|F|
#
# 3. 보너스 점수
#  - 평균 점수가 85점 이상일 경우 +3점 보너스를 평균 점수에 더한 후, 그 값을 기준으로 학점을 계산한다.
# ※ 보너스는 개별 과목 점수가 아닌 평균 점수에만 적용된다.
#
# 4. 최종 성적 출력(반환)
#  - 학생 이름, 과목 점수, 평균 점수, 학점, 보너스 점수를 출력(반환)한다.
#
# ~~5. 여러 학생 성적 처리~~
# ~~- 여러 명의 학생 성적을 처리하고, 전체 평균 점수와 최고 점수를 계산하여 출력한다.~~
# <br>
#
# 함수 이름
#  - student_grades :개별 학생의 성적을 처리 <br>
#  - ~~student_performance :여러 학생의 성적을 처리~~
#
# (반드시 함수 이름을 student_grades~~,student_performance~~ 로 작성할 것!)
# <br>
# <br>
#
#
# 함수 작성 가이드 <br>
#     # 학생 성적 계산 및 출력(반환)<br>
# def student_grades(name, scores):<br>
#     pass
# <br>
# <br>
# ~~#여러 명의 학생에 대해 성적을 처리하는 함수~~<br>
#
# ~~def student_performance():<br>~~
#     ~~pass~~
# <br>
# <br>
#
# * 예시1)
#   - 입력: student_grades("홍길동", [90, 88, 92, 96])<br>
#   - 예상 출력
#    ```
#    이름: 홍길동
#    과목 점수: [90, 88, 92, 96]
#    평균 점수: 91.5
#    학점: A
#    보너스 점수: 3
#   ```
# <br>
#
# * 예시2)
#   * 입력: student_grades("김철수", [78, 76, 66, 80])
#   * 예상 출력
#    ```
#    이름: 김철수
#    과목 점수: [78, 76, 66, 80]
#    평균 점수: 75.0
#    학점: C
#    보너스 점수: 0
#    ```
# <br>
#
# * 예시3)
#   * student_grades("이영희", [20, 11, 88, 90])
#   * 예상 출력
#    ```
#    Invalid Value
#    ```
# ###### 추가 설명 ######
# 최종 성적 출력(반환)
#
# 학생 이름, 과목 점수, 평균 점수, 학점, 보너스 점수를 반환(return) 해야 함.
# ※ print()로 화면에 출력하지 말고, 반드시 return으로 값을 돌려줘야 결과를 활용해야 채점 가능함.
# <br>
# <br>

# %%
###### 예시1번 문제 답안 작성 셀 ######

# %%
###### 예시2번 문제 답안 작성 셀 ######

# %%
###### 예시3번 문제 답안 작성 셀 ######
